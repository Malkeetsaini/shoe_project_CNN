# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/shoe_project
# Out:
# /content/drive/MyDrive/shoe_project

# %%
pwd
# Out:
# '/content/drive/MyDrive/shoe_project'

# %%
pip install torch torchvision pandas pillow scikit-learn tqdm

# %%
# !find data/shoes | head -20
# Out:
# data/shoes
# data/shoes/Sandals
# data/shoes/Sandals/Athletic
# data/shoes/Sandals/Athletic/Sperry Top-Sider
# data/shoes/Sandals/Athletic/Sperry Top-Sider/7266887.18.jpg
# data/shoes/Sandals/Athletic/Keen Kids
# data/shoes/Sandals/Athletic/Keen Kids/7397030.4535.jpg
# data/shoes/Sandals/Athletic/Keen Kids/7500854.43936.jpg
# data/shoes/Sandals/Athletic/Keen Kids/7501314.4535.jpg
# data/shoes/Sandals/Athletic/adidas
# data/shoes/Sandals/Athletic/adidas/115220.151.jpg
# data/shoes/Sandals/Athletic/adidas/115220.20569.jpg
# data/shoes/Sandals/Athletic/adidas/7268762.11682.jpg
# data/shoes/Sandals/Athletic/adidas/7368136.124874.jpg
# data/shoes/Sandals/Athletic/Keen
# data/shoes/Sandals/Athletic/Keen/7596238.3.jpg
# data/shoes/Sandals/Athletic/Keen/7599282.55057.jpg
# data/shoes/Sandals/Athletic/Keen/7599282.221016.jpg
# data/shoes/Sandals/Athletic/Nike
# data/shoes/Sandals/Athletic/Nike/7525639.191707.jpg

# %%
#!python create_csv.py
# Out:
# CSV files created successfully!
# Total images: 26420

# %%
# !python -m datasets.shoe_dataset
# Out:
# ['boot', 'formal']

# %%
# !python -m utils.transforms

# %%
# !python -m models.model

# %%
# !python -m train.py
# Out:
# Streaming output truncated to the last 5000 lines.
#          [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#         [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#          [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#          [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#          ...,
#          [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#          [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#          [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400]]]), 'main_label': 0, 'sub_label': 0, 'type_label': 0}
# {'image': tensor([[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#          ...,
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
# ...
